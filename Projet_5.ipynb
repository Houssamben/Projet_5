# %% [markdown]
# # Fichier ERP : nettoyage

# %%
#importation des librairies
import pandas as pd
import numpy as np

# %%
#chargement du fuhcier ERP
Data_erp = pd.read_excel(r"C:\Users\home\Desktop\FORMATION DATA ANALYST\PROJET_5\erp.xlsx")
Data_erp.head()
# Out:
# C:\Users\home\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    product_id  onsale_web  price  stock_quantity stock_status
# 0        3847           1   24.2               0   outofstock
# 1        3849           1   34.3               0   outofstock
# 2        3850           1   20.8               0   outofstock
# 3        4032           1   14.1               0   outofstock
# 4        4039           1   46.0               0   outofstock

# %%
Data_erp.dtypes
# Out:
# product_id          int64
# onsale_web          int64
# price             float64
# stock_quantity      int64
# stock_status       object
# dtype: object

# %%
Data_erp.info()
# aucune valeur null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      825 non-null    int64
#  1   onsale_web      825 non-null    int64
#  2   price           825 non-null    float64
#  3   stock_quantity  825 non-null    int64
#  4   stock_status    825 non-null    object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 32.4+ KB

# %%
#conversion de product_id en object
Data_erp["product_id"] = Data_erp["product_id"].astype("object")

# %%
Data_erp.describe(include='all')
#825/825 des product_id sont unique
# Out:
#         product_id  onsale_web       price  stock_quantity stock_status
# count        825.0  825.000000  825.000000      825.000000          825
# unique       825.0         NaN         NaN             NaN            2
# top         3847.0         NaN         NaN             NaN      instock
# freq           1.0         NaN         NaN             NaN          638
# mean           NaN    0.869091   32.415636       26.496970          NaN
# std            NaN    0.337506   26.795849       45.892422          NaN
# min            NaN    0.000000    5.200000        0.000000          NaN
# 25%            NaN    1.000000   14.600000        1.000000          NaN
# 50%            NaN    1.000000   24.400000       11.000000          NaN
# 75%            NaN    1.000000   42.000000       34.000000          NaN
# max            NaN    1.000000  225.000000      578.000000          NaN

# %%
#double-check :aucun doublant 
duplicated_Data_erp = Data_erp.duplicated()
duplicated_Data_erp.value_counts()
# Out:
# False    825
# dtype: int64

# %%
#nombre d'articles vendus sur le web :717
nbr_produits_vendus=Data_erp['onsale_web'].sum()
nbr_produits_vendus
# Out:
# 717

# %%
# verifier des erreurs de saisi
Data_erp[(Data_erp["stock_quantity"] == 0 )&(Data_erp["stock_status"] == "instock")]
# Out:
#     product_id  onsale_web  price  stock_quantity stock_status
# 443       4954           1   25.0               0      instock

# %% [markdown]
# # Fichier WEB : nettoyage

# %%
Data_web = pd.read_excel(r"C:\Users\home\Desktop\FORMATION DATA ANALYST\PROJET_5\web.xlsx")
Data_web.head()
# Out:
# C:\Users\home\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                    sku  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros        0             0             0             0.0
# 1                15298        0             0             0             0.0
# 2                15296        0             0             0             0.0
# 3                15300        0             0             0             0.0
# 4                19814        0             0             0             0.0
#
#    total_sales tax_status  tax_class  post_author           post_date  ...  \
# 0         10.0    taxable        NaN          1.0 2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0 2018-02-08 12:58:52  ...
# 2          0.0    taxable        NaN          2.0 2018-02-08 13:49:41  ...
# ...

# %%
Data_web.describe(include = "all", datetime_is_numeric=True)
#nbr d'id unique est 714 (vs 717 nbr d'articles vendus sur le web selon fihcier ERP)
# Out:
#                         sku  virtual  downloadable  rating_count  \
# count                  1428   1513.0        1513.0        1513.0
# unique                  714      NaN           NaN           NaN
# top     bon-cadeau-25-euros      NaN           NaN           NaN
# freq                      2      NaN           NaN           NaN
# mean                    NaN      0.0           0.0           0.0
# min                     NaN      0.0           0.0           0.0
# 25%                     NaN      0.0           0.0           0.0
# 50%                     NaN      0.0           0.0           0.0
# 75%                     NaN      0.0           0.0           0.0
# max                     NaN      0.0           0.0           0.0
# std                     NaN      0.0           0.0           0.0
#
#         average_rating  total_sales tax_status  tax_class  post_author  \
# count           1430.0  1430.000000        716        0.0  1430.000000
# ...

# %%
# 85 lignes avec l'id "sku" null qui seront droppé
Data_web[Data_web['sku'].isnull()]
# Out:
#      sku  virtual  downloadable  rating_count  average_rating  total_sales  \
# 178  NaN        0             0             0             NaN          NaN
# 179  NaN        0             0             0             NaN          NaN
# 227  NaN        0             0             0             NaN          NaN
# 230  NaN        0             0             0             NaN          NaN
# 231  NaN        0             0             0             NaN          NaN
# ..   ...      ...           ...           ...             ...          ...
# 792  NaN        0             0             0             NaN          NaN
# 793  NaN        0             0             0             NaN          NaN
# 794  NaN        0             0             0             NaN          NaN
# 795  NaN        0             0             0             NaN          NaN
# 796  NaN        0             0             0             NaN          NaN
#
#     tax_status  tax_class  post_author post_date  ... post_name  \
# ...

# %%
#supprimer les lignes sans id SKU 1513-85=1428
Data_web_cleaned=Data_web.dropna(axis = 0, subset = ["sku"], inplace = False )
Data_web_cleaned
# Out:
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
# index reset
Data_web_cleaned = pd.DataFrame(Data_web_cleaned).reset_index(drop = "True")

# %%
Data_web_cleaned
# Out:
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1423                16135        0             0             0
# 1424                15891        0             0             0
# 1425                15887        0             0             0
# 1426              13127-1        0             0             0
# 1427                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
#verifier les doublons : 0 doublons
doublons_web=Data_web_cleaned.duplicated()
doublons_web.value_counts()
# Out:
# False    1428
# dtype: int64

# %%
#714 id SKU en double
doublons_sku = Data_web_cleaned["sku"].duplicated()
doublons_sku.value_counts()
# Out:
# False    714
# True     714
# Name: sku, dtype: int64

# %%
# les doublons sont des attachement avec "post_type" =" attachement"
Data_web_cleaned["post_type"].value_counts()
# Out:
# product       714
# attachment    714
# Name: post_type, dtype: int64

# %%
#mettre les lignes avec post_type=product en haut du fichier
Data_web_cleaned.sort_values(by='post_type',ascending=False)
# Out:
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 491                 14827        0             0             0
# 471                 15526        0             0             0
# 472                 16305        0             0             0
# 473                 16306        0             0             0
# ...                   ...      ...           ...           ...
# 953                 15145        0             0             0
# 954                 15801        0             0             0
# 955                 15452        0             0             0
# 956                 15038        0             0             0
# 1427                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
#supprimer les doublons SKU avec post_type='attachement'
Data_web_cleaned.drop_duplicates(subset="sku", keep='first', inplace=True, ignore_index=False)
Data_web_cleaned.shape
# Out:
# (714, 28)

# %%
#verifier qu'il reste que les lignes avec post_type=product
Data_web_cleaned["post_type"].value_counts()
# Out:
# product    714
# Name: post_type, dtype: int64

# %% [markdown]
# # Fichier Liaison :nettoyage

# %%
Data_liaison = pd.read_excel(r"C:\Users\home\Desktop\FORMATION DATA ANALYST\PROJET_5\liaison.xlsx")
Data_liaison.head()
# Out:
# C:\Users\home\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    product_id id_web
# 0        3847  15298
# 1        3849  15296
# 2        3850  15300
# 3        4032  19814
# 4        4039  19815

# %%
Data_liaison.dtypes
# Out:
# product_id     int64
# id_web        object
# dtype: object

# %%
Data_liaison["product_id"] = Data_liaison["product_id"].astype(object)
Data_liaison.dtypes
# Out:
# product_id    object
# id_web        object
# dtype: object

# %%
#825 le meme nombre de product_id dans le fichier ERP  VS 714 nombre d'id SKU
Data_liaison.describe()
# Out:
#         product_id  id_web
# count          825     734
# unique         825     734
# top           3847   15298
# freq             1       1

# %%
#nombre de valeurs null de l'id SKU est 825-734=91
Data_liaison = Data_liaison.rename(columns={"id_web":"sku"})
Data_liaison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  825 non-null    object
#  1   sku         734 non-null    object
# dtypes: object(2)
# memory usage: 13.0+ KB

# %% [markdown]
# # Rapprochement des fichiers

# %%
erp_id_list = Data_erp["product_id"].tolist()
liaison_id_list = Data_liaison["product_id"].tolist()

# %%
# meme clés id_product dans data_erp et data_liaison
set(erp_id_list) - set(liaison_id_list)
# Out:
# set()

# %%
web_sku_list = Data_web_cleaned["sku"].tolist()
liaison_sku_list = Data_liaison["sku"].tolist()

# %%
#list des id SKU qui manquent dans le fichier data_liaison
missing_sku_data_liaison = set(liaison_sku_list) - set(web_sku_list)
missing_sku_data_liaison
# Out:
# {12601,
#  13577,
#  13771,
#  14360,
#  14377,
#  14379,
#  14648,
#  '14680-1',
#  14689,
#  14715,
#  14730,
#  14785,
#  15065,
#  15154,
#  15272,
#  15529,
#  15586,
#  15608,
#  15609,
#  15630,
#  nan}

# %%
#Merge des deux DF Data_web_cleaned et Data_liaison
Data_web_liaison=pd.merge(Data_web_cleaned, Data_liaison, on = "sku", how = "left")

# %%
Data_web_liaison.head()
# Out:
#                    sku  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros        0             0             0             0.0
# 1                15298        0             0             0             0.0
# 2                15296        0             0             0             0.0
# 3                15300        0             0             0             0.0
# 4                19814        0             0             0             0.0
#
#    total_sales tax_status  tax_class  post_author           post_date  ...  \
# 0         10.0    taxable        NaN          1.0 2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0 2018-02-08 12:58:52  ...
# 2          0.0    taxable        NaN          2.0 2018-02-08 13:49:41  ...
# 3          0.0    taxable        NaN          2.0 2018-02-08 14:08:36  ...
# 4          3.0    taxable        NaN          2.0 2018-02-09 14:01:05  ...
#
# ...

# %%
#vérification des valeurs null apres merge
Data_web_liaison["product_id"].isnull().value_counts()
# Out:
# False    714
# Name: product_id, dtype: int64

# %%
#merge entre Data_web_liaison  et Data_ERP
data_web_et_erp = pd.merge(Data_web_liaison,Data_erp, on ="product_id", how = "left")
data_web_et_erp
# Out:
#                      sku  virtual  downloadable  rating_count  average_rating  \
# 0    bon-cadeau-25-euros        0             0             0             0.0
# 1                  15298        0             0             0             0.0
# 2                  15296        0             0             0             0.0
# 3                  15300        0             0             0             0.0
# 4                  19814        0             0             0             0.0
# ..                   ...      ...           ...           ...             ...
# 709                16135        0             0             0             0.0
# 710                15891        0             0             0             0.0
# 711                15887        0             0             0             0.0
# 712              13127-1        0             0             0             0.0
# 713                16230        0             0             0             0.0
#
# ...

# %%
#verification des valeur null pour les colonnes SKU,total_sales,product_id,onsale_web,price
data_web_et_erp.isnull().mean()
# Out:
# sku                      0.0
# virtual                  0.0
# downloadable             0.0
# rating_count             0.0
# average_rating           0.0
# total_sales              0.0
# tax_status               0.0
# tax_class                1.0
# post_author              0.0
# post_date                0.0
# post_date_gmt            0.0
# post_content             1.0
# post_title               0.0
# post_excerpt             0.0
# post_status              0.0
# comment_status           0.0
# ping_status              0.0
# post_password            1.0
# post_name                0.0
# post_modified            0.0
# post_modified_gmt        0.0
# post_content_filtered    1.0
# post_parent              0.0
# guid                     0.0
# menu_order               0.0
# post_type                0.0
# post_mime_type           1.0
# comment_count            0.0
# product_id               0.0
# onsale_web               0.0
# price                    0.0
# stock_quantity           0.0
# ...

# %%
#comparaison des id_product onsale_web et id_product :il manque 3 produits
print(Data_erp["onsale_web"].value_counts())
print(data_web_et_erp["onsale_web"].value_counts())
# Out:
# 1    717
# 0    108
# Name: onsale_web, dtype: int64
# 1    714
# Name: onsale_web, dtype: int64

# %%
#Comparer les product_id des produits qui ont onsale_web=1 dans l erp et
list_onsaleweb_product_id_erp = Data_erp[Data_erp["onsale_web"] == 1]["product_id"].tolist()
list_product_id_web_et_erp = data_web_et_erp["product_id"]

# %%
#product_id des 3 produits manquants
onsale_web_but_not_found_web = set(list_onsaleweb_product_id_erp) - set(list_product_id_web_et_erp)
print(onsale_web_but_not_found_web)
# Out:
# {4594, 5075, 5070}
